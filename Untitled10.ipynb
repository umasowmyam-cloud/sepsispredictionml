# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.datasets import load_iris
iris = load_iris()

X = iris.data
y = iris.target
df = pd.DataFrame(X, columns=iris.feature_names)
df['target'] = y

print(df.head())
print(df.info())
print(df.describe())
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   target             150 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 6.0 KB
# None
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)      target
# count        150.000000  150.000000
# mean           1.199333    1.000000
# std            0.762238    0.819232
# min            0.100000    0.000000
# 25%            0.300000    0.000000
# 50%            1.300000    1.000000
# 75%            1.800000    2.000000
# max            2.500000    2.000000

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical
iris = load_iris()
X = iris.data
y = iris.target
df = pd.DataFrame(X, columns=iris.feature_names)
df['target'] = y
print("First 5 Rows:")
print(df.head())
print("\nDataset Info:")
print(df.info())
print("\nClass Distribution:")
print(df['target'].value_counts())

# Data Preprocessing
print("\nMissing Values:")
print(df.isnull().sum())
# Feature Scaling
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
# One-hot encoding for output
y_encoded = to_categorical(y)

# Train-Test Split (80:20)
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y_encoded,
    test_size=0.2,
    random_state=42
)

# Build ANN Model
model = Sequential()

# Input Layer + Hidden Layer 1
model.add(Dense(10, input_dim=4, activation='relu'))

# Hidden Layer 2
model.add(Dense(8, activation='relu'))

# Output Layer (3 classes)
model.add(Dense(3, activation='softmax'))

# Step 7: Compile Model
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Train Model
history = model.fit(
    X_train,
    y_train,
    epochs=100,
    batch_size=5,
    validation_split=0.1,
    verbose=1
)

# Step 8: Predict Test Data
y_pred = model.predict(X_test)

# Convert probabilities to class labels
y_pred_classes = np.argmax(y_pred, axis=1)
y_test_classes = np.argmax(y_test, axis=1)

# Step 9: Evaluation

# Accuracy
accuracy = accuracy_score(y_test_classes, y_pred_classes)
print("\nAccuracy:", accuracy)

# Confusion Matrix
cm = confusion_matrix(y_test_classes, y_pred_classes)
print("\nConfusion Matrix:\n", cm)

# Precision, Recall, F1-Score
print("\nClassification Report:\n")
print(classification_report(y_test_classes, y_pred_classes))
# Out:
# First 5 Rows:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   target             150 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 6.0 KB
# None
#
# Class Distribution:
# target
# 0    50
# 1    50
# 2    50
# Name: count, dtype: int64
#
# Missing Values:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# target               0
# dtype: int64
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.5282 - loss: 1.0204 - val_accuracy: 0.5833 - val_loss: 1.0286
# Epoch 2/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6458 - loss: 0.9765 - val_accuracy: 0.6667 - val_loss: 0.9874
# Epoch 3/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6809 - loss: 0.9189 - val_accuracy: 0.8333 - val_loss: 0.9374
# Epoch 4/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7532 - loss: 0.8359 - val_accuracy: 0.6667 - val_loss: 0.8855
# Epoch 5/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7705 - loss: 0.7996 - val_accuracy: 0.6667 - val_loss: 0.8359
# Epoch 6/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7582 - loss: 0.7496 - val_accuracy: 0.6667 - val_loss: 0.7881
# Epoch 7/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8044 - loss: 0.6561 - val_accuracy: 0.6667 - val_loss: 0.7448
# Epoch 8/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7335 - loss: 0.6184 - val_accuracy: 0.6667 - val_loss: 0.7070
# Epoch 9/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8195 - loss: 0.5653 - val_accuracy: 0.7500 - val_loss: 0.6739
# Epoch 10/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8253 - loss: 0.5422 - val_accuracy: 0.7500 - val_loss: 0.6462
# Epoch 11/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8349 - loss: 0.4795 - val_accuracy: 0.7500 - val_loss: 0.6222
# Epoch 12/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8237 - loss: 0.4863 - val_accuracy: 0.7500 - val_loss: 0.5993
# Epoch 13/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8528 - loss: 0.4247 - val_accuracy: 0.7500 - val_loss: 0.5803
# Epoch 14/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8426 - loss: 0.4190 - val_accuracy: 0.7500 - val_loss: 0.5652
# Epoch 15/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8223 - loss: 0.4108 - val_accuracy: 0.7500 - val_loss: 0.5512
# Epoch 16/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8543 - loss: 0.3864 - val_accuracy: 0.7500 - val_loss: 0.5397
# Epoch 17/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8024 - loss: 0.4163 - val_accuracy: 0.7500 - val_loss: 0.5274
# Epoch 18/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8676 - loss: 0.3499 - val_accuracy: 0.7500 - val_loss: 0.5192
# Epoch 19/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8047 - loss: 0.3627 - val_accuracy: 0.7500 - val_loss: 0.5104
# Epoch 20/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8467 - loss: 0.3665 - val_accuracy: 0.7500 - val_loss: 0.5011
# Epoch 21/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8491 - loss: 0.3273 - val_accuracy: 0.7500 - val_loss: 0.4942
# Epoch 22/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8459 - loss: 0.3359 - val_accuracy: 0.8333 - val_loss: 0.4866
# Epoch 23/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8478 - loss: 0.3640 - val_accuracy: 0.8333 - val_loss: 0.4800
# Epoch 24/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9099 - loss: 0.2654 - val_accuracy: 0.9167 - val_loss: 0.4698
# Epoch 25/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9025 - loss: 0.3071 - val_accuracy: 0.8333 - val_loss: 0.4677
# Epoch 26/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8587 - loss: 0.3046 - val_accuracy: 0.8333 - val_loss: 0.4610
# Epoch 27/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9033 - loss: 0.2795 - val_accuracy: 0.8333 - val_loss: 0.4531
# Epoch 28/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9025 - loss: 0.2412 - val_accuracy: 0.9167 - val_loss: 0.4437
# Epoch 29/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9079 - loss: 0.2623 - val_accuracy: 0.9167 - val_loss: 0.4344
# Epoch 30/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9112 - loss: 0.2532 - val_accuracy: 0.9167 - val_loss: 0.4273
# Epoch 31/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9326 - loss: 0.2653 - val_accuracy: 0.9167 - val_loss: 0.4203
# Epoch 32/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8870 - loss: 0.2343 - val_accuracy: 0.9167 - val_loss: 0.4129
# Epoch 33/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9185 - loss: 0.2482 - val_accuracy: 0.9167 - val_loss: 0.4075
# Epoch 34/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9122 - loss: 0.2279 - val_accuracy: 0.9167 - val_loss: 0.3955
# Epoch 35/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9046 - loss: 0.2287 - val_accuracy: 0.9167 - val_loss: 0.3921
# Epoch 36/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9124 - loss: 0.2570 - val_accuracy: 0.9167 - val_loss: 0.3741
# Epoch 37/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9437 - loss: 0.2085 - val_accuracy: 0.9167 - val_loss: 0.3752
# Epoch 38/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9644 - loss: 0.2131 - val_accuracy: 0.9167 - val_loss: 0.3722
# Epoch 39/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9424 - loss: 0.1893 - val_accuracy: 0.9167 - val_loss: 0.3622
# Epoch 40/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9693 - loss: 0.1559 - val_accuracy: 0.9167 - val_loss: 0.3520
# Epoch 41/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9443 - loss: 0.2062 - val_accuracy: 0.9167 - val_loss: 0.3486
# Epoch 42/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9677 - loss: 0.1500 - val_accuracy: 0.9167 - val_loss: 0.3377
# Epoch 43/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9678 - loss: 0.1690 - val_accuracy: 0.9167 - val_loss: 0.3291
# Epoch 44/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9277 - loss: 0.1901 - val_accuracy: 0.9167 - val_loss: 0.3242
# Epoch 45/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9525 - loss: 0.1523 - val_accuracy: 0.9167 - val_loss: 0.3209
# Epoch 46/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9532 - loss: 0.1472 - val_accuracy: 0.9167 - val_loss: 0.3196
# Epoch 47/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9810 - loss: 0.1374 - val_accuracy: 0.9167 - val_loss: 0.3117
# Epoch 48/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9415 - loss: 0.1408 - val_accuracy: 0.9167 - val_loss: 0.2944
# Epoch 49/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9855 - loss: 0.1329 - val_accuracy: 0.9167 - val_loss: 0.2904
# Epoch 50/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9621 - loss: 0.1456 - val_accuracy: 0.9167 - val_loss: 0.2927
# Epoch 51/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9391 - loss: 0.1369 - val_accuracy: 0.9167 - val_loss: 0.2828
# Epoch 52/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9447 - loss: 0.1365 - val_accuracy: 0.9167 - val_loss: 0.2861
# Epoch 53/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9514 - loss: 0.1473 - val_accuracy: 0.9167 - val_loss: 0.2761
# Epoch 54/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9531 - loss: 0.1021 - val_accuracy: 0.9167 - val_loss: 0.2610
# Epoch 55/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9471 - loss: 0.1449 - val_accuracy: 0.9167 - val_loss: 0.2682
# Epoch 56/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9670 - loss: 0.1237 - val_accuracy: 0.9167 - val_loss: 0.2611
# Epoch 57/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9355 - loss: 0.1273 - val_accuracy: 0.9167 - val_loss: 0.2662
# Epoch 58/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9622 - loss: 0.1079 - val_accuracy: 0.9167 - val_loss: 0.2527
# Epoch 59/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9367 - loss: 0.1199 - val_accuracy: 0.9167 - val_loss: 0.2623
# Epoch 60/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9799 - loss: 0.0904 - val_accuracy: 0.9167 - val_loss: 0.2560
# Epoch 61/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9425 - loss: 0.1124 - val_accuracy: 0.9167 - val_loss: 0.2555
# Epoch 62/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9576 - loss: 0.1106 - val_accuracy: 0.9167 - val_loss: 0.2561
# Epoch 63/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9650 - loss: 0.0907 - val_accuracy: 0.9167 - val_loss: 0.2442
# Epoch 64/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9782 - loss: 0.0674 - val_accuracy: 0.9167 - val_loss: 0.2496
# Epoch 65/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9746 - loss: 0.0854 - val_accuracy: 0.9167 - val_loss: 0.2398
# Epoch 66/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9588 - loss: 0.0968 - val_accuracy: 0.9167 - val_loss: 0.2397
# Epoch 67/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9677 - loss: 0.0823 - val_accuracy: 0.9167 - val_loss: 0.2469
# Epoch 68/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9608 - loss: 0.0982 - val_accuracy: 0.9167 - val_loss: 0.2389
# Epoch 69/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9362 - loss: 0.1147 - val_accuracy: 0.9167 - val_loss: 0.2422
# Epoch 70/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9758 - loss: 0.0750 - val_accuracy: 0.9167 - val_loss: 0.2439
# Epoch 71/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9598 - loss: 0.0843 - val_accuracy: 0.9167 - val_loss: 0.2393
# Epoch 72/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9751 - loss: 0.0661 - val_accuracy: 0.9167 - val_loss: 0.2425
# Epoch 73/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9384 - loss: 0.0955 - val_accuracy: 0.9167 - val_loss: 0.2251
# Epoch 74/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9815 - loss: 0.0688 - val_accuracy: 0.9167 - val_loss: 0.2352
# Epoch 75/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9553 - loss: 0.0821 - val_accuracy: 0.9167 - val_loss: 0.2329
# Epoch 76/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9647 - loss: 0.0653 - val_accuracy: 0.9167 - val_loss: 0.2473
# Epoch 77/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9512 - loss: 0.0787 - val_accuracy: 0.9167 - val_loss: 0.2263
# Epoch 78/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9644 - loss: 0.0824 - val_accuracy: 0.9167 - val_loss: 0.2281
# Epoch 79/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9443 - loss: 0.0811 - val_accuracy: 0.9167 - val_loss: 0.2437
# Epoch 80/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9777 - loss: 0.0562 - val_accuracy: 0.9167 - val_loss: 0.2284
# Epoch 81/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9283 - loss: 0.0964 - val_accuracy: 0.9167 - val_loss: 0.2328
# Epoch 82/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9571 - loss: 0.0736 - val_accuracy: 0.9167 - val_loss: 0.2292
# Epoch 83/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9688 - loss: 0.0725 - val_accuracy: 0.9167 - val_loss: 0.2491
# Epoch 84/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9762 - loss: 0.0609 - val_accuracy: 0.9167 - val_loss: 0.2353
# Epoch 85/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9524 - loss: 0.0781 - val_accuracy: 0.9167 - val_loss: 0.2314
# Epoch 86/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9661 - loss: 0.0769 - val_accuracy: 0.9167 - val_loss: 0.2423
# Epoch 87/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9664 - loss: 0.0719 - val_accuracy: 0.9167 - val_loss: 0.2379
# Epoch 88/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9413 - loss: 0.1081 - val_accuracy: 0.9167 - val_loss: 0.2400
# Epoch 89/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9587 - loss: 0.0837 - val_accuracy: 0.9167 - val_loss: 0.2395
# Epoch 90/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9761 - loss: 0.0693 - val_accuracy: 0.9167 - val_loss: 0.2352
# Epoch 91/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9447 - loss: 0.1047 - val_accuracy: 0.9167 - val_loss: 0.2481
# Epoch 92/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9580 - loss: 0.0583 - val_accuracy: 0.9167 - val_loss: 0.2300
# Epoch 93/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9700 - loss: 0.0607 - val_accuracy: 0.9167 - val_loss: 0.2574
# Epoch 94/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9870 - loss: 0.0550 - val_accuracy: 0.9167 - val_loss: 0.2308
# Epoch 95/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9429 - loss: 0.0837 - val_accuracy: 0.9167 - val_loss: 0.2576
# Epoch 96/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9785 - loss: 0.0840 - val_accuracy: 0.9167 - val_loss: 0.2547
# Epoch 97/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9455 - loss: 0.0834 - val_accuracy: 0.9167 - val_loss: 0.2503
# Epoch 98/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9736 - loss: 0.0743 - val_accuracy: 0.9167 - val_loss: 0.2580
# Epoch 99/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9321 - loss: 0.1097 - val_accuracy: 0.9167 - val_loss: 0.2411
# Epoch 100/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9860 - loss: 0.0362 - val_accuracy: 0.9167 - val_loss: 0.2481
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step
#
# Accuracy: 1.0
#
# Confusion Matrix:
#  [[10  0  0]
#  [ 0  9  0]
#  [ 0  0 11]]
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      1.00      1.00         9
#            2       1.00      1.00      1.00        11
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30

# %%
# ======================
# EDA VISUALIZATION
# ======================

# Pairplot (relationship between features)
sns.pairplot(df, hue='target')
plt.show()

# Correlation Heatmap
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title("Feature Correlation Heatmap")
plt.show()

# Distribution of Features
df.hist(figsize=(10,8), bins=20)
plt.suptitle("Feature Distributions")
plt.show()

# Boxplot (detect outliers)
plt.figure(figsize=(10,6))
sns.boxplot(data=df.iloc[:, :-1])
plt.title("Boxplot of Features")
plt.show()

# Class distribution
sns.countplot(x='target', data=df)
plt.title("Class Distribution")
plt.show()
